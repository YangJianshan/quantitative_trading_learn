# %% [markdown]
# ## 27 时间处理对象

# %%
import datetime
datetime.datetime.strptime('2010-1-1','%Y-%m-%d')
# Out:
# datetime.datetime(2010, 1, 1, 0, 0)

# %%
import dateutil
dateutil.parser.parse('2010.1.1')
# Out:
# datetime.datetime(2010, 1, 1, 0, 0)

# %%
import pandas as pd
pd.to_datetime(['2010.1.1', '2011.2.2'])
# Out:
# DatetimeIndex(['2010-01-01', '2011-02-02'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ## 28 时间对象生成

# %%
pd.date_range('2010.1.1','2011.1.1', freq="w")
# Out:
# DatetimeIndex(['2010-01-03', '2010-01-10', '2010-01-17', '2010-01-24',
#                '2010-01-31', '2010-02-07', '2010-02-14', '2010-02-21',
#                '2010-02-28', '2010-03-07', '2010-03-14', '2010-03-21',
#                '2010-03-28', '2010-04-04', '2010-04-11', '2010-04-18',
#                '2010-04-25', '2010-05-02', '2010-05-09', '2010-05-16',
#                '2010-05-23', '2010-05-30', '2010-06-06', '2010-06-13',
#                '2010-06-20', '2010-06-27', '2010-07-04', '2010-07-11',
#                '2010-07-18', '2010-07-25', '2010-08-01', '2010-08-08',
#                '2010-08-15', '2010-08-22', '2010-08-29', '2010-09-05',
#                '2010-09-12', '2010-09-19', '2010-09-26', '2010-10-03',
#                '2010-10-10', '2010-10-17', '2010-10-24', '2010-10-31',
#                '2010-11-07', '2010-11-14', '2010-11-21', '2010-11-28',
#                '2010-12-05', '2010-12-12', '2010-12-19', '2010-12-26'],
# ...

# %%
dt = _
dt[0]
# Out:
# Timestamp('2010-01-03 00:00:00', freq='W-SUN')

# %%
pd.date_range('2020.1.1', periods=60)
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10', '2020-01-11', '2020-01-12',
#                '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#                '2020-01-17', '2020-01-18', '2020-01-19', '2020-01-20',
#                '2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24',
#                '2020-01-25', '2020-01-26', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30', '2020-01-31', '2020-02-01',
#                '2020-02-02', '2020-02-03', '2020-02-04', '2020-02-05',
#                '2020-02-06', '2020-02-07', '2020-02-08', '2020-02-09',
#                '2020-02-10', '2020-02-11', '2020-02-12', '2020-02-13',
#                '2020-02-14', '2020-02-15', '2020-02-16', '2020-02-17',
#                '2020-02-18', '2020-02-19', '2020-02-20', '2020-02-21',
# ...

# %%
dt = _

# %%
dt[0].to_pydatetime()
# Out:
# datetime.datetime(2020, 1, 1, 0, 0)

# %% [markdown]
# ## 29 时间序列

# %%
pd.date_range('2020.1.1', '2020.3.3')
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10', '2020-01-11', '2020-01-12',
#                '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#                '2020-01-17', '2020-01-18', '2020-01-19', '2020-01-20',
#                '2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24',
#                '2020-01-25', '2020-01-26', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30', '2020-01-31', '2020-02-01',
#                '2020-02-02', '2020-02-03', '2020-02-04', '2020-02-05',
#                '2020-02-06', '2020-02-07', '2020-02-08', '2020-02-09',
#                '2020-02-10', '2020-02-11', '2020-02-12', '2020-02-13',
#                '2020-02-14', '2020-02-15', '2020-02-16', '2020-02-17',
#                '2020-02-18', '2020-02-19', '2020-02-20', '2020-02-21',
# ...

# %%
import numpy as np
sr = pd.Series(np.arange(1000), index=pd.date_range('2020.1.1', periods=1000))
# sr = pd.Series(pd.date_range('2020.1.1', periods=1000), np.arange(1000))
sr
# Out:
# 2020-01-01      0
# 2020-01-02      1
# 2020-01-03      2
# 2020-01-04      3
# 2020-01-05      4
#              ...
# 2022-09-22    995
# 2022-09-23    996
# 2022-09-24    997
# 2022-09-25    998
# 2022-09-26    999
# Freq: D, Length: 1000, dtype: int32

# %%
sr['2020']
# Out:
# 2020-01-01      0
# 2020-01-02      1
# 2020-01-03      2
# 2020-01-04      3
# 2020-01-05      4
#              ...
# 2020-12-27    361
# 2020-12-28    362
# 2020-12-29    363
# 2020-12-30    364
# 2020-12-31    365
# Freq: D, Length: 366, dtype: int32

# %%
sr['2020':'2021/1']
# Out:
# 2020-01-01      0
# 2020-01-02      1
# 2020-01-03      2
# 2020-01-04      3
# 2020-01-05      4
#              ...
# 2021-01-27    392
# 2021-01-28    393
# 2021-01-29    394
# 2021-01-30    395
# 2021-01-31    396
# Freq: D, Length: 397, dtype: int32

# %%
sr.resample('Y').sum()
# Out:
# 2020-12-31     66795
# 2021-12-31    200020
# 2022-12-31    232685
# Freq: A-DEC, dtype: int32

# %%
sr.truncate( before='2021')
# Out:
# 2021-01-01    366
# 2021-01-02    367
# 2021-01-03    368
# 2021-01-04    369
# 2021-01-05    370
#              ...
# 2022-09-22    995
# 2022-09-23    996
# 2022-09-24    997
# 2022-09-25    998
# 2022-09-26    999
# Freq: D, Length: 634, dtype: int32
