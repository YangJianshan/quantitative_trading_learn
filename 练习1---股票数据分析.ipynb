# %% [markdown]
# ![联系1---股票数据分析](./image/微信图片_20200406225758.jpg)

# %% [markdown]
# ![招商国证生物医药指数](./image/微信图片_20200406225827.jpg)

# %%
import tushare as ts
a = ts.get_hist_data('600848')
print(type(a))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
ts.top_list("2020-4-6")
# Out:
# Empty DataFrame
# Columns: [code, name, pchange, amount, buy, sell, reason, bratio, sratio, date]
# Index: []

# %%
ts.get_latest_news()
# Out:
# list index out of range
