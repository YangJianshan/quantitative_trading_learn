# %% [markdown]
# # DataFrame

# %% [markdown]
# ## 22 DataFrame的创建

# %%
import pandas as pd
pd.DataFrame({'one':[1,2,3],'two':[4,5,6]}, index=['a','b','c'])
# Out:
#    one  two
# a    1    4
# b    2    5
# c    3    6

# %%
df=_
df
# Out:
#    one  two
# a    1    4
# b    2    5
# c    3    6

# %%
# !type nul> test.csv

# %%
df.to_csv('test.csv')

# %% [markdown]
# ## 23 DataFrame常用属性
