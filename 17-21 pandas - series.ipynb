# %% [markdown]
# ## 17 series 介绍

# %%
import pandas as pd
pd.Series([2,3,4,5])
str = pd.Series([2,3,4,5],index=['a', 'b', 'c', 'd'])
str
# Out:
# a    2
# b    3
# c    4
# d    5
# dtype: int64

# %%
str['a']
'a' in str
for v in str:
    print(v)
# Out:
# 2
# 3
# 4
# 5

# %%
str.index
str.values
# Out:
# array([2, 3, 4, 5], dtype=int64)

# %%
sr = pd.Series([1,2,3,4], index=['a','b', 'c', 'd'])
sr
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
sr[1:5]
# Out:
# b    2
# c    3
# d    4
# dtype: int64

# %%
sr['b':'d']
# Out:
# b    2
# c    3
# d    4
# dtype: int64
