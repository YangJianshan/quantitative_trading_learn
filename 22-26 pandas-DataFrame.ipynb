# %% [markdown]
# # DataFrame

# %% [markdown]
# ## 22 DataFrame的创建

# %%
import pandas as pd
pd.DataFrame({'one':[1,2,3],'two':[4,5,6]}, index=['a','b','c'])
# Out:
#    one  two
# a    1    4
# b    2    5
# c    3    6

# %%
df = _
df
# Out:
#    one  two
# a    1    4
# b    2    5
# c    3    6

# %%
# !type nul> test.csv

# %%
df.to_csv('test.csv')

# %% [markdown]
# ## 23 DataFrame常用属性

# %%
df.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
df.values
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]], dtype=int64)

# %%
df.T
# Out:
#      a  b  c
# one  1  2  3
# two  4  5  6

# %%
df.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %%
df.describe()  # 描述
# Out:
#        one  two
# count  3.0  3.0
# mean   2.0  5.0
# std    1.0  1.0
# min    1.0  4.0
# 25%    1.5  4.5
# 50%    2.0  5.0
# 75%    2.5  5.5
# max    3.0  6.0

# %%
df.values
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]], dtype=int64)

# %% [markdown]
# ##  24 索引和切片

# %%
df
# Out:
#    one  two
# a    1    4
# b    2    5
# c    3    6

# %%
df['one']['b']
# Out:
# 2

# %%
df.loc['a':'c','one']
# Out:
# a    1
# b    2
# c    3
# Name: one, dtype: int64

# %%
df.iloc[0:2,0]
# Out:
# a    1
# b    2
# Name: one, dtype: int64

# %% [markdown]
# ## 25 数据对齐与缺失数据的处理

# %%
df = pd.DataFrame({'two':[1,2,3,4], 'one':[5,6,7,8]}, index=['c','d','b','a'])

# %%
df
# Out:
#    two  one
# c    1    5
# d    2    6
# b    3    7
# a    4    8

# %%
df2 = _20

# %%
df2
# Out:
#    one  two
# a    1    4
# b    2    5
# c    3    6

# %%
df + df2
# Out:
#    one  two
# a  9.0  8.0
# b  9.0  8.0
# c  8.0  7.0
# d  NaN  NaN

# %%
df
# Out:
#    two  one
# c    1    5
# d    2    6
# b    3    7
# a    4    8

# %%
import numpy as np
df.loc['c','two'] = np.nan
df
# Out:
#    two  one
# c  NaN    5
# d  2.0    6
# b  3.0    7
# a  4.0    8

# %%
df.dropna()
# Out:
#    two  one
# d  2.0    6
# b  3.0    7
# a  4.0    8

# %%
df
# Out:
#    two  one
# c  NaN    5
# d  2.0    6
# b  3.0    7
# a  4.0    8

# %%
df.dropna(axis=1)
# Out:
#    one
# c    5
# d    6
# b    7
# a    8

# %% [markdown]
# ## 26 pandas 常用函数

# %%
# mean 求平均值
print(df)
df.mean()
# Out:
#    two  one
# c  NaN    5
# d  2.0    6
# b  3.0    7
# a  4.0    8
# two    3.0
# one    6.5
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# c    5.0
# d    4.0
# b    5.0
# a    6.0
# dtype: float64

# %%
# sum 求和
df.sum()
# Out:
# two     9.0
# one    26.0
# dtype: float64

# %%
# 按值排序
df.sort_values(by='two', ascending=False)
# Out:
#    two  one
# a  4.0    8
# b  3.0    7
# d  2.0    6
# c  NaN    5

# %%
# 按标签排序
df.sort_index()
# Out:
#    two  one
# a  4.0    8
# b  3.0    7
# c  NaN    5
# d  2.0    6
